# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import numpy as np

# %%
sales=pd.read_csv("C:/Users/admin/IBM_Training/Training/Numpy - Series, DataFrame, Missing, Group, Merge/Sales_Outliers.csv")

# %%
sales.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
#detecting outliers Function
outlier=[]
def detect_outliers(data):
    threshold=3
    mean=np.mean(data)
    std=np.std(data)
    for i in data:
        z_score=(i-mean)/std
        if np.abs(z_score)>threshold:
            outlier.append(i)
    return outlier

# %%
# Marking the Outliers
x=detect_outliers(sales["Item_Outlet_Sales"])
np.min(x)
# Out:
# 7317.142

# %%
#Checking the Outliers from the dataset
sales[sales["Item_Outlet_Sales"]>7317]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 130            FDY25          NaN          Low Fat         0.033810
# 145            FDP16       18.600          Low Fat         0.039356
# 276            FDY55       16.750          Low Fat         0.081253
# 304            DRE60        9.395          Low Fat         0.159658
# 333            FDN58          NaN          Regular         0.056597
# 373            FDX09        9.000          Low Fat         0.065237
# 456            FDS26          NaN          Low Fat         0.089036
# 472            FDU56          NaN          Low Fat         0.000000
# 661            FDA34          NaN          Low Fat         0.014789
# 694            FDC33          NaN          Regular         0.068605
# 753            FDY26       20.600              reg         0.030511
# 809            FDL24          NaN          Regular         0.024776
# 935            FDV57          NaN          Regular         0.065577
# 991            FDS44          NaN          Regular         0.155288
# 997            FDK28        5.695          Low Fat         0.065961
# 1009           FDU14          NaN          Low Fat         0.034584
# 1138           FDM21          NaN          Low Fat         0.064052
# 1254           FDG47       12.800          Low Fat         0.069619
# 1450           FDZ20          NaN          Low Fat         0.000000
# 1506           FDB15       10.895          Low Fat         0.137023
# 1859           FDW56          NaN          Low Fat         0.070557
# 1998           FDZ43          NaN          Regular         0.056782
# 2109           FDU55          NaN          Low Fat         0.035737
# 2216           FDT16        9.895          Regular         0.048761
# 2238           FDU38          NaN          Low Fat         0.082150
# 2293           FDR45       10.800          Low Fat         0.029002
# 2516           FDJ38        8.600          Regular         0.040206
# 2535           FDD44        8.050          Regular         0.078844
# 2776           FDB37       20.250          Regular         0.022936
# 3083           FDJ15       11.350          Regular         0.023318
# ...              ...          ...              ...              ...
# 5977           FDK09          NaN          Low Fat         0.091319
# 6000           FDO37          NaN          Low Fat         0.021273
# 6134           FDF40          NaN          Regular         0.022403
# 6334           FDF41          NaN          Low Fat         0.130545
# 6409           FDA21       13.650          Low Fat         0.035931
# 6537           FDR52          NaN          Regular         0.075676
# 6541           FDI50          NaN          Regular         0.030693
# 6606           DRF36          NaN          Low Fat         0.023463
# 6886           FDX13          NaN          Low Fat         0.047552
# 6993           FDT21        7.420          Low Fat         0.020507
# 7016           NCD18          NaN          Low Fat         0.072317
# 7076           FDR34       17.000          Regular         0.016056
# 7188           NCE42          NaN          Low Fat         0.010551
# 7191           NCH18          NaN          Low Fat         0.044445
# 7236           NCE55          NaN          Low Fat         0.129299
# 7256           DRJ39       20.250          Low Fat         0.036400
# 7302           FDX58          NaN          Low Fat         0.043552
# 7343           FDR37          NaN          Regular         0.065929
# 7560           FDB56        8.750          Regular         0.074565
# 7562           FDY39          NaN          Regular         0.000000
# 7609           FDT07          NaN          Regular         0.076945
# 7690           FDQ37          NaN          Low Fat         0.088828
# 7752           FDC17          NaN          Low Fat         0.015386
# 7816           FDV45          NaN          Low Fat         0.044829
# 7826           FDM39          NaN          Low Fat         0.053212
# 7930           FDP15          NaN          Low Fat         0.083536
# 8039           FDY55       16.750          Low Fat         0.081485
# 8201           FDO03          NaN          Regular         0.036704
# 8245           FDU55       16.200          Low Fat         0.035967
# 8447           FDS26       20.350          Low Fat         0.089975
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
#
# 991                        1985      Medium               Tier 3
# 997                        2007         NaN               Tier 2
# 1009                       1985      Medium               Tier 3
# 1138                       1985      Medium               Tier 3
# 1254                       1997       Small               Tier 1
# 1450                       1985      Medium               Tier 3
# 1506                       1999      Medium               Tier 1
# 1859                       1985      Medium               Tier 3
# 1998                       1985      Medium               Tier 3
# 2109                       1985      Medium               Tier 3
# 2216                       2002         NaN               Tier 2
# 2238                       1985      Medium               Tier 3
# 2293                       2002         NaN               Tier 2
# 2516                       1997       Small               Tier 1
# 2535                       2007         NaN               Tier 2
# 2776                       2004       Small               Tier 2
# 3083                       2004       Small               Tier 2
# ...                         ...         ...                  ...
# 5977                       1985      Medium               Tier 3
# 6000                       1985      Medium               Tier 3
# 6134                       1985      Medium               Tier 3
# 6334                       1985      Medium               Tier 3
# 6409                       1987        High               Tier 3
# 6537                       1985      Medium               Tier 3
# 6541                       1985      Medium               Tier 3
# 6606                       1985      Medium               Tier 3
# 6886                       1985      Medium               Tier 3
# 6993                       2007         NaN               Tier 2
# 7016                       1985      Medium               Tier 3
# 7076                       2007         NaN               Tier 2
# 7188                       1985      Medium               Tier 3
# 7191                       1985      Medium               Tier 3
# 7236                       1985      Medium               Tier 3
# 7256                       2002         NaN               Tier 2
# 7302                       1985      Medium               Tier 3
# 7343                       1985      Medium               Tier 3
# 7560                       1987        High               Tier 3
# 7562                       1985      Medium               Tier 3
# 7609                       1985      Medium               Tier 3
# 7690                       1985      Medium               Tier 3
# 7752                       1985      Medium               Tier 3
# 7816                       1985      Medium               Tier 3
# 7826                       1985      Medium               Tier 3
# 7930                       1985      Medium               Tier 3
# 8039                       2002         NaN               Tier 2
# 8201                       1985      Medium               Tier 3
# 8245                       1999      Medium               Tier 1
# 8447                       2007         NaN               Tier 2
#
#             Outlet_Type  Item_Outlet_Sales
# 130   Supermarket Type3          7968.2944
# 145   Supermarket Type1          7370.4060
# 276   Supermarket Type1          7452.9652
# 304   Supermarket Type1          7696.6480
# 333   Supermarket Type3          9267.9360
# 373   Supermarket Type1          7763.2280
# 456   Supermarket Type3          9158.0790
# 472   Supermarket Type3          8114.7704
# 661   Supermarket Type3          7443.6440
# 694   Supermarket Type3          7488.9184
# 753   Supermarket Type1          7833.8028
# 809   Supermarket Type3          7759.8990
# 935   Supermarket Type3          7370.4060
# 991   Supermarket Type3          9133.4444
# 997   Supermarket Type1          9275.9256
# 1009  Supermarket Type3         10236.6750
# 1138  Supermarket Type3          7472.2734
# 1254  Supermarket Type1          8132.0812
# 1450  Supermarket Type3         11445.1020
# 1506  Supermarket Type1          7646.0472
# 1859  Supermarket Type3          7504.2318
# 1998  Supermarket Type3          8239.9408
# 2109  Supermarket Type3          9371.8008
# 2216  Supermarket Type1          8851.1452
# 2238  Supermarket Type3          7478.2656
# 2293  Supermarket Type1          8604.7992
# 2516  Supermarket Type1          7590.1200
# 2535  Supermarket Type1          8760.5964
# 2776  Supermarket Type1          7931.6754
# 3083  Supermarket Type1          7534.1928
# ...                 ...                ...
# 5977  Supermarket Type3          8474.3024
# 6000  Supermarket Type3          7393.0432
# 6134  Supermarket Type3          8217.3036
# 6334  Supermarket Type3          7883.0720
# 6409  Supermarket Type1          9069.5276
# 6537  Supermarket Type3          8789.8916
# 6541  Supermarket Type3         10306.5840
# 6606  Supermarket Type3          9554.2300
# 6886  Supermarket Type3          8217.3036
# 6993  Supermarket Type1          7719.2852
# 7016  Supermarket Type3          8062.8380
# 7076  Supermarket Type1          8245.2672
# 7188  Supermarket Type3         13086.9648
# 7191  Supermarket Type3         10072.8882
# 7236  Supermarket Type3          7939.6650
# 7256  Supermarket Type1          8323.8316
# 7302  Supermarket Type3          7873.0850
# 7343  Supermarket Type3          8209.3140
# 7560  Supermarket Type1          7322.4684
# 7562  Supermarket Type3          7717.9536
# 7609  Supermarket Type3          7433.6570
# 7690  Supermarket Type3          7943.6598
# 7752  Supermarket Type3          9678.0688
# 7816  Supermarket Type3          7510.2240
# 7826  Supermarket Type3          8417.7094
# 7930  Supermarket Type3          9227.9880
# 8039  Supermarket Type1          8994.9580
# 8201  Supermarket Type3          9390.4432
# 8245  Supermarket Type1          7549.5062
# 8447  Supermarket Type1          7588.1226
#
# [90 rows x 12 columns]

# %% [markdown]
# # Standardization
#
# Data standardization is the process of rescaling one or more attributes so that they have a mean value of 0 and a standard deviation of 1.
#
# Standardization assumes that your data has a Gaussian (bell curve) distribution. This does not strictly have to be true, but the technique is more effective if your attribute distribution is Gaussian

# %%
#Standardization
from sklearn.preprocessing import StandardScaler
scaling=StandardScaler()
abc=scaling.fit_transform(sales[["Item_Outlet_Sales"]])

# %%
abc[abc>=3]
# Out:
# array([3.39135442, 3.04097433, 3.08935644, 3.23216168, 4.15298239,
#        3.27117951, 4.08860298, 3.47719364, 3.08389394, 3.11042607,
#        3.31253841, 3.26922862, 3.04097433, 4.07416638, 4.15766453,
#        4.72069177, 3.10067161, 3.48733827, 5.42886533, 3.20250814,
#        3.11940017, 3.55054715, 4.2138502 , 3.9087308 , 3.10418321,
#        3.76436484, 3.16973316, 3.85566655, 3.36989461, 3.13695819,
#        3.3180009 , 4.27003587, 3.9446272 , 3.11900999, 3.49124005,
#        3.01990471, 3.02926899, 3.44714991, 3.16388049, 3.9715495 ,
#        4.45302948, 4.14361812, 5.16432446, 3.25869381, 3.56381321,
#        3.6519935 , 4.73239712, 4.38552864, 3.70817917, 3.42686064,
#        3.20250814, 3.6375569 , 5.82294538, 3.22591883, 4.32544119,
#        3.17675637, 3.91887543, 3.69101133, 3.07296895, 3.00976007,
#        3.6878899 , 3.05424039, 3.53728109, 3.3414116 , 4.03670927,
#        3.8728344 , 4.76166049, 4.32075905, 3.53728109, 3.24542775,
#        3.44675973, 3.55366858, 6.39104493, 4.62470792, 3.37457675,
#        3.59970961, 3.33555893, 3.53259895, 3.0128815 , 3.24464739,
#        3.07804127, 3.37691782, 4.39333221, 3.12291177, 3.65472475,
#        4.1295717 , 3.9930093 , 4.2247752 , 3.14593229, 3.16856263])

# %% [markdown]
# # Normalization
#
# Data normalization is the process of rescaling one or more attributes to the range of 0 to 1. This means that the largest value for each attribute is 1 and the smallest value is 0. Basically the requirement of Normalization is used where we want to eliminate the units in dataset like height of car in inches vs the weight of the car in Kg or Pound.

# %%
from sklearn.preprocessing import MinMaxScaler
scaling=MinMaxScaler()
abc=scaling.fit_transform(sales[["Item_Outlet_Sales"]])

# %%
abc
# Out:
# array([[0.28358666],
#        [0.03141895],
#        [0.15811486],
#        ...,
#        [0.08885035],
#        [0.13883505],
#        [0.05610527]])
